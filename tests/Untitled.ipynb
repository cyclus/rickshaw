# %%
import matplotlib.pyplot as plt

simulations = [1,10,100,1000, 2000]
megabytes = [0.246, 0.463, 3.177, 57.094, 115.577]

plt.loglog(simulations, megabytes, 'ro-')
plt.xlabel('Simulations')
plt.ylabel('Megabytes')
plt.show()
